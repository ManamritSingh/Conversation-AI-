# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
from nltk.collocations import *
Bigram_Measures = nltk.collocations.BigramAssocMeasures()
Find = BigramCollocationFinder.from_words(text5)
Find.nbest(Bigram_Measures.pmi,100)
# Out:
# [('!...', 'lotsa'),
#  ("'n'", 'Cream'),
#  ('*sniffs*', 'ewwwwww'),
#  (',,,,,,,', 'babblein'),
#  ('-s', 'woooohoooo'),
#  ('........................', 'CHATHIDE'),
#  ('..............................', 'Boyz'),
#  ('.45', 'barrel'),
#  ('100%', 'cotton'),
#  ('185', 'pounds'),
#  ('220', 'lb'),
#  ('360', 'minigames'),
#  ('700', 'yards'),
#  ('73%', '-17'),
#  ('8082653953', 'K-Fed'),
#  ('818', 'CALI'),
#  (':o *', '=O'),
#  ('<-', 'defragging'),
#  ('=p', 'Marlaya'),
#  ('AROUND', 'TELLIN'),
#  ('ASS', 'GIRL'),
#  ('Advisory',
#   '//www.wunderground.com/cgi-bin/findweather/getForecast?query=95953#FIR'),
#  ('Almost', 'Home'),
#  ('Average', 'Stalker'),
#  ('BLONDES', 'RIGHT'),
#  ('Bone', 'Thugs'),
#  ('Bonus', 'Track'),
#  ('Books', 'Froogle'),
#  ('Boyz', 'II'),
#  ('Breaking', 'Benjamin'),
#  ('Burger', 'King'),
#  ('CAN', 'BE'),
#  ('Came', 'Covered'),
#  ('Chat', 'scream'),
#  ('Children', 'Cry'),
#  ('Chingy', 'feat'),
#  ('Ciara', 'ft.'),
#  ('Clock', 'Tower'),
# ...

# %%
my_set = ["My" , "Favourite" , "Subject" , "Is" , "NLP"]
my_set
# Out:
# ['My', 'Favourite', 'Subject', 'Is', 'NLP']

# %%
def listToString(s):
 
    str1 = ""
 
    for ele in s:
        str1 = str1 + ele + ' '
 
    return str1

newString = listToString(my_set)

# %%
newString
# Out:
# 'My Favourite Subject Is NLP '

# %%
newList = list(newString.split(' '))
newList
# Out:
# ['My', 'Favourite', 'Subject', 'Is', 'NLP', '']

# %%
text9.index('sunset')
# Out:
# 629

# %%
sorted(set([w.lower() for w in text1]))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
sorted([w.lower() for w in set(text1)])
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
# observed difference : Nothing basically
# tokenisation is happening before in 1st and later in 2nd results are the same though
# Out:
# {'injured',
#  'Mazeppa',
#  'disputes',
#  'loudly',
#  'FROCK',
#  'experiences',
#  'untottering',
#  'language',
#  'extreme',
#  'Dr',
#  'hang',
#  'thickets',
#  'tone',
#  'recrossing',
#  'lowermost',
#  'blaze',
#  'vacancy',
#  'uses',
#  'privateers',
#  'flinging',
#  'punctual',
#  'unspeckled',
#  'mansion',
#  'undergraduate',
#  'continuing',
#  'towing',
#  'Nay',
#  'fadest',
#  'gave',
#  'troubled',
#  'wanting',
#  'backstays',
#  'panting',
#  'prospect',
#  'rushed',
#  'Pious',
#  'triune',
#  'Assuming',
#  'sleep',
#  'occupant',
#  'upcast',
#  'sires',
#  'festival',
#  'Indiaman',
#  'beware',
#  'talks',
#  'tranquil',
#  'holding',
#  'Landlord',
#  'spraining',
#  'impediments',
#  'Must',
#  'honourably',
#  'concluded',
#  'triangular',
#  'capricious',
#  'semicircle',
#  'appropriate',
#  'benevolent',
#  'Tash',
#  'admitting',
#  'generous',
#  'lads',
#  'traditions',
#  'gas',
#  'counterbalance',
#  'LANTERNS',
#  'omnipresence',
# ...

# %%
len(set(text2))
# Out:
# 6833

# %%
text2[6832:6834]
# Out:
# ['one', 'moment']

# %%
freqdist = FreqDist(text5)

# %%
text5FourLetterWords = sorted(set([w for w in text5 if w.isalpha() and len(w) == 4]))
for sample in [w for w in freqdist]:
    if sample not in text5FourLetterWords:
        freqdist.pop(sample)
freqdist
# Out:
# FreqDist({'JOIN': 1021, 'PART': 1016, 'that': 274, 'what': 183, 'here': 181, 'have': 164, 'like': 156, 'with': 152, 'chat': 142, 'your': 137, ...})

# %%
for w in set(text6):
  if w.isupper():
    print(w)
# Out:
# FATHER
# ARMY
# TIM
# LAUNCELOT
# OF
# U
# OLD
# SECOND
# I
# WINSTON
# BRIDE
# OFFICER
# GOD
# Y
# SIR
# CART
# MONKS
# GALAHAD
# PRINCESS
# OTHER
# AMAZING
# PATSY
# PIGLET
# CUSTOMER
# FRENCH
# W
# PRINCE
# CARTOON
# CRONE
# B
# RIGHT
# PERSON
# MAN
# CRAPPER
# CROWD
# NARRATOR
# HEADS
# BROTHER
# ROGER
# CHARACTERS
# STUNNER
# ARTHUR
# N
# VILLAGERS
# GUARDS
# INSPECTOR
# LUCKY
# ROBIN
# GUESTS
# SHRUBBER
# ANIMATOR
# SUN
# LOVELY
# SCENE
# WIFE
# KING
# MIDDLE
# MASTER
# HERBERT
# GIRLS
# A
# MAYNARD
# CAMERAMAN
# DINGO
# SENTRY
# CRASH
# SOLDIER
# BORS
# BEDEVERE
# GREEN
# DEAD
# BLACK
# VILLAGER
# LEFT
# BRIDGEKEEPER
# DENNIS
# WOMAN
# VOICE
# KNIGHT
# CONCORDE
# THE
# PARTY
# GUEST
# CHARACTER
# MIDGET
# NI
# ENCHANTER
# PRISONER
# S
# ALL
# C
# MINSTREL
# RANDOM
# DIRECTOR
# ZOOT
# HISTORIAN
# HEAD
# WITCH
# O
# KNIGHTS
# GUARD

# %%
for w in set(text6):
  if w.endswith("ize") or (w.find("z")!=-1) or (w.find("pt")!=-1) or (w[0].isupper() and w[1:].islower()):
    print(w)
# Out:
# Come
# Quite
# Olfin
# Hic
# How
# Anybody
# Hiyya
# Loimbard
# Will
# Grenade
# Open
# Honestly
# Beast
# Burn
# Mind
# Steady
# Anthrax
# Hurry
# Running
# Camaaaaaargue
# amazes
# Camelot
# Oooooooh
# They
# Quick
# Shrubber
# ptoo
# Hyy
# Consult
# Winter
# Brother
# No
# If
# Aagh
# Throw
# His
# Hallo
# Forward
# Eh
# Sorry
# Death
# Ho
# Mother
# Between
# We
# Uugh
# Til
# That
# European
# Hold
# Erm
# Practice
# Winston
# Exactly
# Ahh
# Chop
# England
# Iesu
# Lie
# Dingo
# Packing
# Tis
# Hey
# Providence
# Hang
# Bedwere
# Two
# Off
# Shut
# Dragon
# Thpppppt
# Forgive
# Defeat
# Thee
# Am
# Aaaah
# Wood
# Bravest
# Nothing
# Charge
# Looks
# More
# Joseph
# Tower
# My
# Bloody
# Three
# Chapter
# Wait
# Aaaugh
# For
# Today
# Oooohoohohooo
# Would
# You
# Must
# Bristol
# Five
# aptly
# Tell
# Skip
# Augh
# temptress
# Nu
# Does
# Ages
# Lead
# Aramaic
# Ecky
# Churches
# Which
# Chickennn
# Cornwall
# Ow
# Peril
# She
# Dennis
# Man
# zoo
# Prepare
# Bors
# Remove
# ...

# %%
sent=['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']
for w in sent:
  if w[0:2]=="sh":
    print(w)
# Out:
# she
# shells
# shore

# %%
sum=0
for w in text6:
  sum+=len(w)
print(sum/len(text6))
# Out:
# 3.115518359167796

# %%
print(len(set(text6)))
fdist = FreqDist(text6)
vocabulary = fdist.keys()
print(len(vocabulary))
# Out:
# 2166
# 2166

# %%
for w in set(text6):
  print(w," : ",100*text6.count(w)/len((text6)))
# Out:
# tough  :  0.005893793835091648
# donkey  :  0.005893793835091648
# recover  :  0.005893793835091648
# smashed  :  0.005893793835091648
# Come  :  0.15323863971238286
# fortune  :  0.005893793835091648
# vital  :  0.005893793835091648
# again  :  0.058937938350916486
# kneecaps  :  0.005893793835091648
# Quite  :  0.011787587670183296
# mad  :  0.005893793835091648
# distributing  :  0.005893793835091648
# particular  :  0.005893793835091648
# drink  :  0.005893793835091648
# quest  :  0.07661931985619143
# has  :  0.06483173218600813
# fell  :  0.017681381505274946
# Olfin  :  0.005893793835091648
# clank  :  0.017681381505274946
# general  :  0.005893793835091648
# wonderful  :  0.005893793835091648
# nervous  :  0.005893793835091648
# nothing  :  0.03536276301054989
# impeccable  :  0.005893793835091648
# Hic  :  0.053044144515824836
# haw  :  0.04125655684564154
# How  :  0.058937938350916486
# weighs  :  0.005893793835091648
# dungeon  :  0.005893793835091648
# ...
